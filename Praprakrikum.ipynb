# %%
print("welcome to hell")
# Out:
# welcome to hell

# %%
print("Muhammad Hafidz Luthfi")
print("2605060022")
# Out:
# Muhammad Hafidz Luthfi
# 2605060022

# %% [markdown]
# https://medium.com/@welldone1134/pra-praktikum-3878664962e7?postPublishedType=initial
