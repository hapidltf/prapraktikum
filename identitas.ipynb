# %% [markdown]
# <a href="https://colab.research.google.com/github/hapidltf/prapraktikum/blob/main/identitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Nama: Muhammad Hafidz Luthfi")
print("NPM: 2605060022")
print("TTL: Magelang, 14 Agustus 2008")
print("Jenis Kelamin: Laki Laki")           #print adalah perintah dasar untuk menampilkan teks angka variabel dll.
print("Alamat: Secang")
print("Hobi: Main Game")
# Out:
# Nama: Muhammad Hafidz Luthfi
# NPM: 2605060022
# TTL: Magelang, 14 Agustus 2008
# Jenis Kelamin: Laki Laki
# Alamat: Secang
# Hobi: Main Game

# %%
a = 10;
b = 6;
                  #ini adalah contoh tipe data integer
print(a + b)
# Out:
# 16

# %%
print("hello world") #ini adalah contoh tipe data string
# Out:
# hello world

# %% [markdown]
# https://medium.com/@welldone1134/penugasan-pengenalan-praktikum-436aea7f9c9c?sharedUserId=welldone1134
